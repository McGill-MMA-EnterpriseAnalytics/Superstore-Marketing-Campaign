# %%
import pandas as pd

# %%
df = pd.read_parquet('artifacts/data/processed/train.parquet')

# %%
df.iloc[0].to_json()
# Out:
# {"year_birth":1966,"education":"Graduate","marital_status":"Single","income":11.4028092143,"kidhome":0,"teenhome":0,"recency":44,"mntwines":6.4085287911,"mntfruits":3.2188758249,"mntmeatproducts":6.882437471,"mntfishproducts":5.2882670307,"mntsweetproducts":5.2729995586,"mntgoldprods":4.1743872699,"numdealspurchases":0.6931471806,"numwebpurchases":2.0794415417,"numcatalogpurchases":2.0794415417,"numstorepurchases":9,"numwebvisitsmonth":4,"complain":0,"total_spend":2059,"mntwines_ratio":0.2943033364,"mntfruits_ratio":0.0115881747,"mntmeatproducts_ratio":0.4730221942,"mntfishproducts_ratio":0.0913686648,"mntsweetproducts_ratio":0.0900380516,"mntgoldprods_ratio":0.0306082906,"premium_ratio":0.3253848769,"age":59,"has_children":0,"total_children":0,"family_size":1,"income_per_family_member":11.4028092143,"recency_score":0.2075775735,"is_active":0,"channel_diversity":3,"webvisit_to_order_ratio":0.4054651081,"enrollments_year":2012,"enrollments_month":9,"customer_tenure_days":4607,"custome
# ...

# %%
{
  "features": {
    "year_birth": 1966,
    "education": "Graduate",
    "maritalstatus": "Single",
    "income": 11.4028092143,
    "kidhome": 0,
    "teenhome": 0,
    "recency": 44,
    "mntwines": 6.4085287911,
    "mntfruits": 3.2188758249,
    "mntmeatproducts": 6.882437471,
    "mntfishproducts": 5.2882670307,
    "mntsweetproducts": 5.2729995586,
    "mntgoldprods": 4.1743872699,
    "numdealspurchases": 0.6931471806,
    "numwebpurchases": 2.0794415417,
    "numcatalogpurchases": 2.0794415417,
    "numstorepurchases": 9,
    "numwebvisitsmonth": 4,
    "complain": 0,
    "totalspend": 2059,
    "mntwinesratio": 0.2943033364,
    "mntfruitsratio": 0.0115881747,
    "mntmeatproductsratio": 0.4730221942,
    "mntfishproductsratio": 0.0913686648,
    "mntsweetproductsratio": 0.0900380516,
    "mntgoldprodsratio": 0.0306082906,
    "premiumratio": 0.3253848769,
    "age": 59,
    "haschildren": 0,
    "totalchildren": 0,
    "familysize": 1,
    "incomeperfamilymember": 11.4028092143,
    "recencyscore": 0.2075775735,
    "isactive": 0,
    "channeldiversity": 3,
    "webvisittoorderratio": 0.4054651081,
    "enrollmentsyear": 2012,
    "enrollmentsmonth": 9,
    "customertenuredays": 4607,
    "customertenureyears": 12.6132785763,
    "incomeageinteraction": 15.4803356833,
    "spendrecencyinteraction": 6.1654121027,
    "ishighvalue": 1,
    "clv": 161.9566493128,
    "agegroup<35": false,
    "agegroup35-50": false,
    "agegroup51-65": true,
    "agegroup66-100": false,
    "agegroup>100": false,
    "preferredchannelcatalog": false,
    "preferredchannelstore": true,
    "preferredchannelweb": false,
    "customersegment": 3
  }
}
